# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

from mini_3d.dataset import ModelNetPointCloudDataset
from mini_3d.utils import visualize_point_cloud, convert_point_cloud_to_ply

# %%
root = "../data/ModelNet10_PointCloud_1024"
dataset = ModelNetPointCloudDataset(root)

# %%
dataset.labels
# Out:
# ['bathtub',
#  'bed',
#  'chair',
#  'desk',
#  'dresser',
#  'monitor',
#  'night_stand',
#  'sofa',
#  'table',
#  'toilet']

# %%
len(dataset)
# Out:
# 3991

# %%
dataset.labels
# Out:
# ['bathtub',
#  'bed',
#  'chair',
#  'desk',
#  'dresser',
#  'monitor',
#  'night_stand',
#  'sofa',
#  'table',
#  'toilet']

# %%
item = dataset[2]
item
# Out:
# (tensor([[-10.1764,  36.0000,  -9.2015],
#          [-36.0000,  30.0322,  11.4859],
#          [  8.9820,  32.0245,  10.4829],
#          ...,
#          [-30.4289,  -7.2338,  10.6053],
#          [ 29.6010,  -2.0433,  -2.0413],
#          [ -7.2721, -27.8100,  12.3750]]),
#  0)

# %%
visualize_point_cloud(item[0])

# %%
convert_point_cloud_to_ply(item[0], "test.ply")
