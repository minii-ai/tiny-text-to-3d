# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

from mini_3d.dataset import ModelNetPointCloudDataset
from mini_3d.utils import visualize_point_cloud, convert_point_cloud_to_mesh
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
root = "../data/ModelNet10_PointCloud_1024"
dataset = ModelNetPointCloudDataset(root)

# %%
dataset.labels
# Out:
# ['bathtub',
#  'bed',
#  'chair',
#  'desk',
#  'dresser',
#  'monitor',
#  'night_stand',
#  'sofa',
#  'table',
#  'toilet']

# %%
len(dataset)
# Out:
# 3991

# %%
dataset.labels
# Out:
# ['bathtub',
#  'bed',
#  'chair',
#  'desk',
#  'dresser',
#  'monitor',
#  'night_stand',
#  'sofa',
#  'table',
#  'toilet']

# %%
item = dataset[0]
item
# Out:
# (tensor([[-16.9985,   5.3446,  -0.2524],
#          [-17.6281,   1.8866,  -1.7217],
#          [-15.4992,  12.5007,  -6.0388],
#          ...,
#          [ 22.8284, -18.2897,   6.1528],
#          [ 15.4581,  -1.5258,  -5.0000],
#          [  2.5237,  21.1716,   5.1510]]),
#  0)

# %%
visualize_point_cloud(item[0])

# %%
convert_point_cloud_to_mesh(item[0]).export("./test.obj")
# Out:
# '# https://github.com/mikedh/trimesh\nv -16.99850273 5.34464693 -0.25242865\nv -17.62810326 1.88664639 -1.72167599\nv 10.03441620 19.17160034 7.71507740\nv 1.70226502 -22.68243408 2.50270796\nv -18.34939766 -22.82839966 0.36663863\nv 22.82839966 14.95329762 3.14490271\nv 22.82839966 -9.96108246 -8.92487812\nv 24.41191483 -5.54724121 -10.00000000\nv -3.88988185 3.95050311 -4.97104263\nv 2.44239688 2.53154659 -5.00000000\nv -13.86559391 5.64915609 -0.42926976\nv -7.79701567 -4.24392557 -5.00000000\nv 13.09273243 21.17160034 4.14405394\nv 18.41963005 -22.82839966 4.93676090\nv 23.03326607 -8.75150204 -10.00000000\nv -10.49136066 11.85178947 3.57042003\nv 22.82839966 8.34512329 -8.29298878\nv -16.95206451 2.56268597 -1.49578011\nv -19.17160034 -12.14110184 -5.06098127\nv 18.13941956 -22.82839966 1.21745217\nv 22.82839966 -8.66955853 -0.88930166\nv 22.82839966 16.02326393 -2.62533975\nv 11.27870274 19.17160034 4.14602137\nv 23.63427162 -2.91466999 -10.00000000\nv -1.06114662 -22.82839966 
# ...
